# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %% [markdown]
# ## Observations:

# %% [markdown]
# 1. Max temperature's are observed around +/- 20 degree latitude's.
#
# 2. Both cloud cover and humidity does not seem to have a strong correlation to latitude.
#
# 3. Wind speeds appear to be slightly higher as we move away from the equator and max wind speeds are recorded around +/- 60 degress latitude.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from pprint import pprint
import openweathermapy.core as owm

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs=[]
cities=[]

lats = np.random.uniform(low=-90,high=90,size=1500)
lngs = np.random.uniform(low=-180,high=180,size=1500)

lat_lngs=zip(lats,lngs)
#print(list(lat_lngs))

for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0],lat_lng[1]).city_name
    
    if city not in cities:
        cities.append(city)
df = pd.DataFrame({"City":cities})
print(df.count())
df.head()
# Out:
# City    607
# dtype: int64
#                 City
# 0         nelson bay
# 1  careiro da varzea
# 2              asosa
# 3        velka bites
# 4            mataura

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it's being processed (with the city number and city name).

# %%
# weather_data=[]
# print("-----------------------------------------")
# print("Beginning Data Retrieval")
# print("-----------------------------------------")
# for index,row in df.iterrows():
#     try:
#         city=row["City"]
#         print(f"Processing Record {index}| {city})")
#         weather_data.append(owm.get_current(row["City"],**settings))
#     except:
#         print(f"{city} not found... Skipping!")
#     time.sleep(.2)
# print("-----------------------------------------")
# print("Data Retrieval Complete")
# print("-----------------------------------------")

# %%
# List to store weather Data
weather_data=[]

# Creating settings dictionary to query keys and values 
settings={"units":"imperial","appid":api_key}

print("-----------------------------------------")
print("Beginning Data Retrieval")
print("-----------------------------------------")
j=1
i=1
# Looping through to cities List to make API calls
for city in cities:
    if(j<50):
        try:
            print(f"Processing Record {j} of Set {i}| {city})")
            weather_data.append(owm.get_current(city,**settings))
        except:
            print(f"{city} not found... Skipping!")
        j+=1
    else:
        j=1
        i+=1
    time.sleep(.1)
print("-----------------------------------------")
print("Beginning Data Complete")
print("-----------------------------------------")
# Out:
# -----------------------------------------
# Beginning Data Retrieval
# -----------------------------------------
# Processing Record 1 of Set 1| nelson bay)
# Processing Record 2 of Set 1| careiro da varzea)
# Processing Record 3 of Set 1| asosa)
# Processing Record 4 of Set 1| velka bites)
# Processing Record 5 of Set 1| mataura)
# Processing Record 6 of Set 1| rikitea)
# Processing Record 7 of Set 1| hobart)
# Processing Record 8 of Set 1| ushuaia)
# Processing Record 9 of Set 1| humaita)
# Processing Record 10 of Set 1| lakatoro)
# Processing Record 11 of Set 1| upernavik)
# Processing Record 12 of Set 1| carnarvon)
# Processing Record 13 of Set 1| castro)
# Processing Record 14 of Set 1| tombouctou)
# Processing Record 15 of Set 1| jamestown)
# Processing Record 16 of Set 1| tura)
# Processing Record 17 of Set 1| tuktoyaktuk)
# Processing Record 18 of Set 1| shar)
# Processing Record 19 of Set 1| qaanaaq)
# Processing Record 20 of Set 1| sao filipe)
# Processing Record 21 of Set 1| lebu)
# Processing Record 22 of Set 1| norman wells)
# Processing Record 23 of Set 1| vaini)
# Processing Record 24 of Set 1| busselton)
# Processing Record 25 of Set 1| albany)
# Processing Record 26 of Set 1| barrow)
# Processing Record 27 of Set 1| east london)
# Processing Record 28 of Set 1| ballina)
# Processing Record 29 of Set 1| belushya guba)
# belushya guba not found... Skipping!
# Processing Record 30 of Set 1| falealupo)
# falealupo not found... Skipping!
# Processing Record 31 of Set 1| illoqqortoormiut)
# illoqqortoormiut not found... Skipping!
# Processing Record 32 of Set 1| saquarema)
# Processing Record 33 of Set 1| ekibastuz)
# Processing Record 34 of Set 1| sinnamary)
# Processing Record 35 of Set 1| melendugno)
# Processing Record 36 of Set 1| ponta do sol)
# Processing Record 37 of Set 1| aklavik)
# Processing Record 38 of Set 1| verkh-usugli)
# Processing Record 39 of Set 1| ambilobe)
# Processing Record 40 of Set 1| avarua)
# Processing Record 41 of Set 1| bonga)
# Processing Record 42 of Set 1| bulgan)
# Processing Record 43 of Set 1| leshukonskoye)
# Processing Record 44 of Set 1| tiksi)
# Processing Record 45 of Set 1| naryan-mar)
# Processing Record 46 of Set 1| mar del plata)
# Processing Record 47 of Set 1| severo-kurilsk)
# Processing Record 48 of Set 1| linjiang)
# Processing Record 49 of Set 1| atuona)
# Processing Record 1 of Set 2| yellowknife)
# Processing Record 2 of Set 2| lasa)
# Processing Record 3 of Set 2| port alfred)
# Processing Record 4 of Set 2| vaitupu)
# vaitupu not found... Skipping!
# Processing Record 5 of Set 2| saleaula)
# saleaula not found... Skipping!
# Processing Record 6 of Set 2| kapaa)
# Processing Record 7 of Set 2| bosaso)
# Processing Record 8 of Set 2| asau)
# asau not found... Skipping!
# Processing Record 9 of Set 2| poyarkovo)
# Processing Record 10 of Set 2| zhigansk)
# Processing Record 11 of Set 2| souillac)
# Processing Record 12 of Set 2| catarman)
# Processing Record 13 of Set 2| nikolskoye)
# Processing Record 14 of Set 2| tasiilaq)
# Processing Record 15 of Set 2| quthing)
# Processing Record 16 of Set 2| urumqi)
# urumqi not found... Skipping!
# Processing Record 17 of Set 2| cidreira)
# Processing Record 18 of Set 2| zverinogolovskoye)
# Processing Record 19 of Set 2| santa cruz cabralia)
# Processing Record 20 of Set 2| filadelfia)
# Processing Record 21 of Set 2| galiwinku)
# galiwinku not found... Skipping!
# Processing Record 22 of Set 2| pangnirtung)
# Processing Record 23 of Set 2| arman)
# Processing Record 24 of Set 2| jiddah)
# jiddah not found... Skipping!
# Processing Record 25 of Set 2| moranbah)
# Processing Record 26 of Set 2| phibun mangsahan)
# Processing Record 27 of Set 2| inhambane)
# Processing Record 28 of Set 2| punta arenas)
# Processing Record 29 of Set 2| attawapiskat)
# attawapiskat not found... Skipping!
# Processing Record 30 of Set 2| kyren)
# Processing Record 31 of Set 2| kodiak)
# Processing Record 32 of Set 2| kruisfontein)
# Processing Record 33 of Set 2| kargopol)
# Processing Record 34 of Set 2| nizhneyansk)
# nizhneyansk not found... Skipping!
# Processing Record 35 of Set 2| salalah)
# Processing Record 36 of Set 2| hobyo)
# Processing Record 37 of Set 2| sisimiut)
# Processing Record 38 of Set 2| norfolk)
# Processing Record 39 of Set 2| eureka)
# Processing Record 40 of Set 2| vila do maio)
# Processing Record 41 of Set 2| puerto ayora)
# Processing Record 42 of Set 2| new norfolk)
# Processing Record 43 of Set 2| imeni babushkina)
# Processing Record 44 of Set 2| worland)
# Processing Record 45 of Set 2| beringovskiy)
# Processing Record 46 of Set 2| chuy)
# Processing Record 47 of Set 2| sharjah)
# Processing Record 48 of Set 2| svetlyy)
# svetlyy not found... Skipping!
# Processing Record 49 of Set 2| santiago)
# Processing Record 1 of Set 3| yulara)
# Processing Record 2 of Set 3| novoagansk)
# Processing Record 3 of Set 3| solnechnyy)
# Processing Record 4 of Set 3| adrar)
# Processing Record 5 of Set 3| manga)
# Processing Record 6 of Set 3| hermanus)
# Processing Record 7 of Set 3| codrington)
# Processing Record 8 of Set 3| corrales)
# Processing Record 9 of Set 3| vysokogornyy)
# Processing Record 10 of Set 3| vredendal)
# Processing Record 11 of Set 3| port elizabeth)
# Processing Record 12 of Set 3| geraldton)
# Processing Record 13 of Set 3| mareeba)
# Processing Record 14 of Set 3| lalibela)
# Processing Record 15 of Set 3| awjilah)
# Processing Record 16 of Set 3| aguie)
# Processing Record 17 of Set 3| tumannyy)
# tumannyy not found... Skipping!
# Processing Record 18 of Set 3| burns lake)
# Processing Record 19 of Set 3| amderma)
# amderma not found... Skipping!
# Processing Record 20 of Set 3| butaritari)
# Processing Record 21 of Set 3| cape town)
# Processing Record 22 of Set 3| broome)
# Processing Record 23 of Set 3| rocha)
# Processing Record 24 of Set 3| talnakh)
# Processing Record 25 of Set 3| ostrovnoy)
# Processing Record 26 of Set 3| ijaki)
# ijaki not found... Skipping!
# Processing Record 27 of Set 3| ulaangom)
# Processing Record 28 of Set 3| ribeira grande)
# Processing Record 29 of Set 3| faya)
# Processing Record 30 of Set 3| komsomolskiy)
# Processing Record 31 of Set 3| acapulco)
# Processing Record 32 of Set 3| teya)
# Processing Record 33 of Set 3| minden)
# Processing Record 34 of Set 3| bredasdorp)
# Processing Record 35 of Set 3| dobryanka)
# Processing Record 36 of Set 3| korla)
# korla not found... Skipping!
# Processing Record 37 of Set 3| tsihombe)
# tsihombe not found... Skipping!
# Processing Record 38 of Set 3| clyde river)
# Processing Record 39 of Set 3| mezen)
# Processing Record 40 of Set 3| abu dhabi)
# Processing Record 41 of Set 3| nanortalik)
# Processing Record 42 of Set 3| esperance)
# Processing Record 43 of Set 3| richards bay)
# Processing Record 44 of Set 3| southampton)
# Processing Record 45 of Set 3| zorgo)
# zorgo not found... Skipping!
# Processing Record 46 of Set 3| samalaeulu)
# samalaeulu not found... Skipping!
# Processing Record 47 of Set 3| hithadhoo)
# Processing Record 48 of Set 3| airai)
# Processing Record 49 of Set 3| chicama)
# Processing Record 1 of Set 4| roald)
# Processing Record 2 of Set 4| wazzan)
# wazzan not found... Skipping!
# Processing Record 3 of Set 4| taunggyi)
# Processing Record 4 of Set 4| ardakan)
# Processing Record 5 of Set 4| vostok)
# Processing Record 6 of Set 4| manakara)
# Processing Record 7 of Set 4| labuhan)
# Processing Record 8 of Set 4| bengkulu)
# bengkulu not found... Skipping!
# Processing Record 9 of Set 4| sao sebastiao)
# Processing Record 10 of Set 4| coahuayana)
# Processing Record 11 of Set 4| arraial do cabo)
# Processing Record 12 of Set 4| biak)
# Processing Record 13 of Set 4| navrongo)
# Processing Record 14 of Set 4| cherskiy)
# Processing Record 15 of Set 4| nokaneng)
# Processing Record 16 of Set 4| thompson)
# Processing Record 17 of Set 4| hilo)
# Processing Record 18 of Set 4| iqaluit)
# Processing Record 19 of Set 4| marystown)
# Processing Record 20 of Set 4| ancud)
# Processing Record 21 of Set 4| luderitz)
# Processing Record 22 of Set 4| taolanaro)
# taolanaro not found... Skipping!
# Processing Record 23 of Set 4| port hardy)
# Processing Record 24 of Set 4| chagda)
# chagda not found... Skipping!
# Processing Record 25 of Set 4| saint george)
# Processing Record 26 of Set 4| talaja)
# Processing Record 27 of Set 4| quang ngai)
# Processing Record 28 of Set 4| provideniya)
# Processing Record 29 of Set 4| kharp)
# Processing Record 30 of Set 4| vila velha)
# Processing Record 31 of Set 4| dunedin)
# Processing Record 32 of Set 4| berlevag)
# Processing Record 33 of Set 4| gigmoto)
# Processing Record 34 of Set 4| denpasar)
# Processing Record 35 of Set 4| victoria)
# Processing Record 36 of Set 4| fountain)
# Processing Record 37 of Set 4| bodden town)
# Processing Record 38 of Set 4| dvinskoy)
# Processing Record 39 of Set 4| alice springs)
# Processing Record 40 of Set 4| sabha)
# Processing Record 41 of Set 4| mys shmidta)
# mys shmidta not found... Skipping!
# Processing Record 42 of Set 4| boyolangu)
# Processing Record 43 of Set 4| wismar)
# Processing Record 44 of Set 4| huron)
# Processing Record 45 of Set 4| laguna)
# Processing Record 46 of Set 4| north bend)
# Processing Record 47 of Set 4| mayo)
# Processing Record 48 of Set 4| tuatapere)
# Processing Record 49 of Set 4| pahrump)
# Processing Record 1 of Set 5| lompoc)
# Processing Record 2 of Set 5| vanimo)
# Processing Record 3 of Set 5| barentsburg)
# barentsburg not found... Skipping!
# Processing Record 4 of Set 5| rio gallegos)
# Processing Record 5 of Set 5| thessalon)
# Processing Record 6 of Set 5| bucerias)
# Processing Record 7 of Set 5| morlaix)
# Processing Record 8 of Set 5| klaksvik)
# Processing Record 9 of Set 5| qiongshan)
# Processing Record 10 of Set 5| constitucion)
# Processing Record 11 of Set 5| ferrol)
# Processing Record 12 of Set 5| zelenoborsk)
# Processing Record 13 of Set 5| ambulu)
# Processing Record 14 of Set 5| tripoli)
# Processing Record 15 of Set 5| mayumba)
# Processing Record 16 of Set 5| svetlogorsk)
# Processing Record 17 of Set 5| havelock)
# Processing Record 18 of Set 5| robertsganj)
# Processing Record 19 of Set 5| sentyabrskiy)
# sentyabrskiy not found... Skipping!
# Processing Record 20 of Set 5| charters towers)
# Processing Record 21 of Set 5| mahebourg)
# Processing Record 22 of Set 5| praia da vitoria)
# Processing Record 23 of Set 5| kurilsk)
# Processing Record 24 of Set 5| idah)
# Processing Record 25 of Set 5| manzanillo)
# Processing Record 26 of Set 5| westport)
# Processing Record 27 of Set 5| avera)
# Processing Record 28 of Set 5| necochea)
# Processing Record 29 of Set 5| manvi)
# Processing Record 30 of Set 5| narsaq)
# Processing Record 31 of Set 5| yinchuan)
# Processing Record 32 of Set 5| grand river south east)
# grand river south east not found... Skipping!
# Processing Record 33 of Set 5| juneau)
# Processing Record 34 of Set 5| lysa hora)
# Processing Record 35 of Set 5| grindavik)
# Processing Record 36 of Set 5| tabou)
# Processing Record 37 of Set 5| angoche)
# Processing Record 38 of Set 5| chokurdakh)
# Processing Record 39 of Set 5| mount isa)
# Processing Record 40 of Set 5| vardo)
# Processing Record 41 of Set 5| bambous virieux)
# Processing Record 42 of Set 5| aksarka)
# Processing Record 43 of Set 5| kirakira)
# Processing Record 44 of Set 5| grand centre)
# grand centre not found... Skipping!
# Processing Record 45 of Set 5| ciudad guayana)
# Processing Record 46 of Set 5| lorengau)
# Processing Record 47 of Set 5| golubitskaya)
# Processing Record 48 of Set 5| wad rawah)
# Processing Record 49 of Set 5| nanga eboko)
# Processing Record 1 of Set 6| puerto leguizamo)
# Processing Record 2 of Set 6| saint-louis)
# Processing Record 3 of Set 6| ulagan)
# Processing Record 4 of Set 6| datong)
# Processing Record 5 of Set 6| haapu)
# haapu not found... Skipping!
# Processing Record 6 of Set 6| alofi)
# Processing Record 7 of Set 6| saint-philippe)
# Processing Record 8 of Set 6| boguchany)
# Processing Record 9 of Set 6| parrita)
# Processing Record 10 of Set 6| hovd)
# Processing Record 11 of Set 6| palasa)
# palasa not found... Skipping!
# Processing Record 12 of Set 6| valdivia)
# Processing Record 13 of Set 6| hami)
# Processing Record 14 of Set 6| winnemucca)
# Processing Record 15 of Set 6| hirara)
# Processing Record 16 of Set 6| faanui)
# Processing Record 17 of Set 6| harper)
# Processing Record 18 of Set 6| sambava)
# Processing Record 19 of Set 6| tocantinopolis)
# tocantinopolis not found... Skipping!
# Processing Record 20 of Set 6| okhotsk)
# Processing Record 21 of Set 6| luena)
# Processing Record 22 of Set 6| vytegra)
# Processing Record 23 of Set 6| palmer)
# Processing Record 24 of Set 6| ormara)
# Processing Record 25 of Set 6| lata)
# Processing Record 26 of Set 6| guerrero negro)
# Processing Record 27 of Set 6| flin flon)
# Processing Record 28 of Set 6| georgetown)
# Processing Record 29 of Set 6| wilmington)
# Processing Record 30 of Set 6| rudnaya pristan)
# Processing Record 31 of Set 6| san patricio)
# Processing Record 32 of Set 6| opuwo)
# Processing Record 33 of Set 6| monte escobedo)
# Processing Record 34 of Set 6| petropavlovsk-kamchatskiy)
# Processing Record 35 of Set 6| polunochnoye)
# Processing Record 36 of Set 6| atambua)
# Processing Record 37 of Set 6| flinders)
# Processing Record 38 of Set 6| pontianak)
# Processing Record 39 of Set 6| comodoro rivadavia)
# Processing Record 40 of Set 6| portland)
# Processing Record 41 of Set 6| kijang)
# Processing Record 42 of Set 6| husavik)
# Processing Record 43 of Set 6| khani)
# Processing Record 44 of Set 6| xinyu)
# Processing Record 45 of Set 6| la canada flintridge)
# Processing Record 46 of Set 6| teguise)
# Processing Record 47 of Set 6| kabare)
# Processing Record 48 of Set 6| herat)
# Processing Record 49 of Set 6| baruun-urt)
# Processing Record 1 of Set 7| itanhaem)
# Processing Record 2 of Set 7| inirida)
# Processing Record 3 of Set 7| zhangjiakou)
# Processing Record 4 of Set 7| mogzon)
# Processing Record 5 of Set 7| lavrentiya)
# Processing Record 6 of Set 7| katobu)
# Processing Record 7 of Set 7| torbay)
# Processing Record 8 of Set 7| safford)
# Processing Record 9 of Set 7| tiznit)
# Processing Record 10 of Set 7| podgorodnyaya pokrovka)
# Processing Record 11 of Set 7| sao miguel do araguaia)
# Processing Record 12 of Set 7| abrau-dyurso)
# Processing Record 13 of Set 7| touros)
# Processing Record 14 of Set 7| baghdad)
# Processing Record 15 of Set 7| kahului)
# Processing Record 16 of Set 7| manggar)
# Processing Record 17 of Set 7| kaitangata)
# Processing Record 18 of Set 7| sigerfjord)
# sigerfjord not found... Skipping!
# Processing Record 19 of Set 7| davila)
# Processing Record 20 of Set 7| sobolevo)
# Processing Record 21 of Set 7| pacov)
# Processing Record 22 of Set 7| makakilo city)
# Processing Record 23 of Set 7| el reno)
# Processing Record 24 of Set 7| aras)
# Processing Record 25 of Set 7| mindelo)
# Processing Record 26 of Set 7| fez)
# Processing Record 27 of Set 7| vila franca do campo)
# Processing Record 28 of Set 7| dzhusaly)
# dzhusaly not found... Skipping!
# Processing Record 29 of Set 7| cabo san lucas)
# Processing Record 30 of Set 7| san cristobal)
# Processing Record 31 of Set 7| kapit)
# Processing Record 32 of Set 7| college)
# Processing Record 33 of Set 7| bilma)
# Processing Record 34 of Set 7| leningradskiy)
# Processing Record 35 of Set 7| puerto escondido)
# Processing Record 36 of Set 7| dalvik)
# Processing Record 37 of Set 7| kununurra)
# Processing Record 38 of Set 7| rio grande)
# Processing Record 39 of Set 7| vao)
# Processing Record 40 of Set 7| evensk)
# Processing Record 41 of Set 7| samusu)
# samusu not found... Skipping!
# Processing Record 42 of Set 7| henties bay)
# Processing Record 43 of Set 7| la ronge)
# Processing Record 44 of Set 7| ponta delgada)
# Processing Record 45 of Set 7| leh)
# Processing Record 46 of Set 7| andenes)
# andenes not found... Skipping!
# Processing Record 47 of Set 7| palabuhanratu)
# palabuhanratu not found... Skipping!
# Processing Record 48 of Set 7| saint-pierre)
# Processing Record 49 of Set 7| ixtapa)
# Processing Record 1 of Set 8| saskylakh)
# Processing Record 2 of Set 8| collie)
# Processing Record 3 of Set 8| loubomo)
# loubomo not found... Skipping!
# Processing Record 4 of Set 8| deputatskiy)
# Processing Record 5 of Set 8| bellevue)
# Processing Record 6 of Set 8| dikson)
# Processing Record 7 of Set 8| palana)
# Processing Record 8 of Set 8| aranos)
# Processing Record 9 of Set 8| ossora)
# Processing Record 10 of Set 8| oxford)
# Processing Record 11 of Set 8| malkara)
# Processing Record 12 of Set 8| alyangula)
# Processing Record 13 of Set 8| san felipe)
# Processing Record 14 of Set 8| marcona)
# marcona not found... Skipping!
# Processing Record 15 of Set 8| bandarbeyla)
# Processing Record 16 of Set 8| ilulissat)
# Processing Record 17 of Set 8| pevek)
# Processing Record 18 of Set 8| lazaro cardenas)
# Processing Record 19 of Set 8| dingle)
# Processing Record 20 of Set 8| bethel)
# Processing Record 21 of Set 8| campbell river)
# Processing Record 22 of Set 8| marsa matruh)
# Processing Record 23 of Set 8| tilichiki)
# Processing Record 24 of Set 8| nsanje)
# Processing Record 25 of Set 8| sumbawa)
# sumbawa not found... Skipping!
# Processing Record 26 of Set 8| kuruman)
# Processing Record 27 of Set 8| kjollefjord)
# Processing Record 28 of Set 8| abu samrah)
# Processing Record 29 of Set 8| la baule-escoublac)
# Processing Record 30 of Set 8| fort nelson)
# Processing Record 31 of Set 8| vangaindrano)
# Processing Record 32 of Set 8| praia)
# Processing Record 33 of Set 8| zugdidi)
# Processing Record 34 of Set 8| bor)
# bor not found... Skipping!
# Processing Record 35 of Set 8| isangel)
# Processing Record 36 of Set 8| burnie)
# Processing Record 37 of Set 8| lagoa)
# Processing Record 38 of Set 8| quatre cocos)
# Processing Record 39 of Set 8| laizhou)
# Processing Record 40 of Set 8| vyartsilya)
# Processing Record 41 of Set 8| kieta)
# Processing Record 42 of Set 8| guanay)
# Processing Record 43 of Set 8| oranjestad)
# Processing Record 44 of Set 8| longyearbyen)
# Processing Record 45 of Set 8| weligama)
# Processing Record 46 of Set 8| belmonte)
# Processing Record 47 of Set 8| port augusta)
# Processing Record 48 of Set 8| siocon)
# Processing Record 49 of Set 8| gataivai)
# Processing Record 1 of Set 9| tigil)
# Processing Record 2 of Set 9| sorbhog)
# Processing Record 3 of Set 9| gao)
# Processing Record 4 of Set 9| nushki)
# Processing Record 5 of Set 9| safaqis)
# safaqis not found... Skipping!
# Processing Record 6 of Set 9| tual)
# Processing Record 7 of Set 9| san quintin)
# Processing Record 8 of Set 9| malmo)
# Processing Record 9 of Set 9| olinda)
# Processing Record 10 of Set 9| bintulu)
# Processing Record 11 of Set 9| coihaique)
# Processing Record 12 of Set 9| prestwich)
# Processing Record 13 of Set 9| skagastrond)
# skagastrond not found... Skipping!
# Processing Record 14 of Set 9| coquimbo)
# Processing Record 15 of Set 9| mumford)
# Processing Record 16 of Set 9| northam)
# Processing Record 17 of Set 9| turukhansk)
# Processing Record 18 of Set 9| maiduguri)
# Processing Record 19 of Set 9| zaterechnyy)
# Processing Record 20 of Set 9| fort-shevchenko)
# Processing Record 21 of Set 9| matara)
# Processing Record 22 of Set 9| port blair)
# Processing Record 23 of Set 9| lodja)
# Processing Record 24 of Set 9| kamenka)
# Processing Record 25 of Set 9| maragogi)
# Processing Record 26 of Set 9| saint-jean-port-joli)
# saint-jean-port-joli not found... Skipping!
# Processing Record 27 of Set 9| karratha)
# Processing Record 28 of Set 9| victor harbor)
# Processing Record 29 of Set 9| la asuncion)
# Processing Record 30 of Set 9| jumla)
# Processing Record 31 of Set 9| lavumisa)
# Processing Record 32 of Set 9| toftir)
# toftir not found... Skipping!
# Processing Record 33 of Set 9| sorland)
# Processing Record 34 of Set 9| katsuura)
# Processing Record 35 of Set 9| at-bashi)
# Processing Record 36 of Set 9| sobinka)
# Processing Record 37 of Set 9| meulaboh)
# Processing Record 38 of Set 9| sao joao da barra)
# Processing Record 39 of Set 9| novokizhinginsk)
# Processing Record 40 of Set 9| hit)
# Processing Record 41 of Set 9| pasir gudang)
# Processing Record 42 of Set 9| khorinsk)
# Processing Record 43 of Set 9| sarangani)
# Processing Record 44 of Set 9| dunajska streda)
# Processing Record 45 of Set 9| pagudpud)
# Processing Record 46 of Set 9| srednekolymsk)
# Processing Record 47 of Set 9| hambantota)
# Processing Record 48 of Set 9| orlik)
# Processing Record 49 of Set 9| pisco)
# Processing Record 1 of Set 10| sant feliu de guixols)
# Processing Record 2 of Set 10| ahipara)
# Processing Record 3 of Set 10| redmond)
# Processing Record 4 of Set 10| rio tuba)
# Processing Record 5 of Set 10| mount gambier)
# Processing Record 6 of Set 10| novyye burasy)
# Processing Record 7 of Set 10| kizhinga)
# Processing Record 8 of Set 10| trinidad)
# Processing Record 9 of Set 10| andapa)
# Processing Record 10 of Set 10| suzu)
# suzu not found... Skipping!
# Processing Record 11 of Set 10| linchuan)
# linchuan not found... Skipping!
# Processing Record 12 of Set 10| umzimvubu)
# umzimvubu not found... Skipping!
# Processing Record 13 of Set 10| emerald)
# Processing Record 14 of Set 10| bara)
# Processing Record 15 of Set 10| cardoso)
# Processing Record 16 of Set 10| sompeta)
# Processing Record 17 of Set 10| asyut)
# Processing Record 18 of Set 10| tara)
# Processing Record 19 of Set 10| goderich)
# Processing Record 20 of Set 10| hinton)
# Processing Record 21 of Set 10| ngunguru)
# Processing Record 22 of Set 10| xam nua)
# Processing Record 23 of Set 10| naples)
# Processing Record 24 of Set 10| sitka)
# Processing Record 25 of Set 10| shetpe)
# Processing Record 26 of Set 10| cazaje)
# cazaje not found... Skipping!
# Processing Record 27 of Set 10| bull savanna)
# Processing Record 28 of Set 10| praya)
# Processing Record 29 of Set 10| hervey bay)
# Processing Record 30 of Set 10| almaznyy)
# Processing Record 31 of Set 10| contai)
# Processing Record 32 of Set 10| plettenberg bay)
# Processing Record 33 of Set 10| sola)
# Processing Record 34 of Set 10| thinadhoo)
# Processing Record 35 of Set 10| uruzgan)
# Processing Record 36 of Set 10| george)
# Processing Record 37 of Set 10| karauzyak)
# karauzyak not found... Skipping!
# Processing Record 38 of Set 10| dourados)
# Processing Record 39 of Set 10| blagoyevo)
# Processing Record 40 of Set 10| fomboni)
# Processing Record 41 of Set 10| ajdabiya)
# Processing Record 42 of Set 10| kavieng)
# Processing Record 43 of Set 10| prince rupert)
# Processing Record 44 of Set 10| walvis bay)
# Processing Record 45 of Set 10| mae sai)
# Processing Record 46 of Set 10| jiroft)
# jiroft not found... Skipping!
# Processing Record 47 of Set 10| mahibadhoo)
# Processing Record 48 of Set 10| murgab)
# Processing Record 49 of Set 10| iranshahr)
# Processing Record 1 of Set 11| klyuchevskiy)
# Processing Record 2 of Set 11| geresk)
# geresk not found... Skipping!
# Processing Record 3 of Set 11| sivaki)
# Processing Record 4 of Set 11| saryshagan)
# saryshagan not found... Skipping!
# Processing Record 5 of Set 11| xingcheng)
# Processing Record 6 of Set 11| zalari)
# Processing Record 7 of Set 11| turayf)
# Processing Record 8 of Set 11| grimshaw)
# Processing Record 9 of Set 11| carutapera)
# Processing Record 10 of Set 11| mercedes)
# Processing Record 11 of Set 11| hofn)
# Processing Record 12 of Set 11| roma)
# Processing Record 13 of Set 11| anjozorobe)
# Processing Record 14 of Set 11| fairbanks)
# Processing Record 15 of Set 11| boditi)
# Processing Record 16 of Set 11| camocim)
# Processing Record 17 of Set 11| axim)
# Processing Record 18 of Set 11| port shepstone)
# Processing Record 19 of Set 11| umm kaddadah)
# Processing Record 20 of Set 11| itarema)
# Processing Record 21 of Set 11| kangaatsiaq)
# Processing Record 22 of Set 11| lerwick)
# Processing Record 23 of Set 11| chipinge)
# Processing Record 24 of Set 11| ruatoria)
# ruatoria not found... Skipping!
# Processing Record 25 of Set 11| sebrovo)
# Processing Record 26 of Set 11| huilong)
# Processing Record 27 of Set 11| grants)
# Processing Record 28 of Set 11| nouadhibou)
# Processing Record 29 of Set 11| alexandria)
# Processing Record 30 of Set 11| cristobal obregon)
# Processing Record 31 of Set 11| marrakesh)
# Processing Record 32 of Set 11| hidalgo)
# Processing Record 33 of Set 11| port lincoln)
# Processing Record 34 of Set 11| russell)
# Processing Record 35 of Set 11| doctor pedro p. pena)
# doctor pedro p. pena not found... Skipping!
# Processing Record 36 of Set 11| pangody)
# Processing Record 37 of Set 11| haibowan)
# haibowan not found... Skipping!
# Processing Record 38 of Set 11| kimberley)
# Processing Record 39 of Set 11| pacific grove)
# Processing Record 40 of Set 11| isilkul)
# Processing Record 41 of Set 11| balikpapan)
# Processing Record 42 of Set 11| riyadh)
# Processing Record 43 of Set 11| manavalakurichi)
# Processing Record 44 of Set 11| lovington)
# Processing Record 45 of Set 11| bima)
# Processing Record 46 of Set 11| fortuna)
# Processing Record 47 of Set 11| shimoda)
# Processing Record 48 of Set 11| lyubokhna)
# Processing Record 49 of Set 11| novorzhev)
# Processing Record 1 of Set 12| charlottetown)
# Processing Record 2 of Set 12| viedma)
# Processing Record 3 of Set 12| namatanai)
# Processing Record 4 of Set 12| sayat)
# Processing Record 5 of Set 12| zharkent)
# Processing Record 6 of Set 12| shelburne)
# Processing Record 7 of Set 12| terrace bay)
# Processing Record 8 of Set 12| katangli)
# Processing Record 9 of Set 12| puerto maldonado)
# Processing Record 10 of Set 12| cabra)
# Processing Record 11 of Set 12| yar-sale)
# Processing Record 12 of Set 12| manado)
# Processing Record 13 of Set 12| saint-joseph)
# Processing Record 14 of Set 12| yabrud)
# Processing Record 15 of Set 12| estelle)
# Processing Record 16 of Set 12| ishigaki)
# Processing Record 17 of Set 12| bathsheba)
# Processing Record 18 of Set 12| mmabatho)
# Processing Record 19 of Set 12| maniitsoq)
# Processing Record 20 of Set 12| matveyevka)
# Processing Record 21 of Set 12| qandala)
# Processing Record 22 of Set 12| mackenzie)
# Processing Record 23 of Set 12| sibolga)
# Processing Record 24 of Set 12| zyryanovsk)
# Processing Record 25 of Set 12| senador guiomard)
# Processing Record 26 of Set 12| tacuarembo)
# Processing Record 27 of Set 12| buraydah)
# Processing Record 28 of Set 12| shirokiy)
# Processing Record 29 of Set 12| liverpool)
# Processing Record 30 of Set 12| barbar)
# barbar not found... Skipping!
# Processing Record 31 of Set 12| samarai)
# Processing Record 32 of Set 12| acajutla)
# Processing Record 33 of Set 12| morros)
# Processing Record 34 of Set 12| ati)
# Processing Record 35 of Set 12| havoysund)
# Processing Record 36 of Set 12| manicore)
# Processing Record 37 of Set 12| awassa)
# awassa not found... Skipping!
# Processing Record 38 of Set 12| liku)
# Processing Record 39 of Set 12| george town)
# Processing Record 40 of Set 12| kisangani)
# Processing Record 41 of Set 12| bardiyah)
# bardiyah not found... Skipping!
# Processing Record 42 of Set 12| sangar)
# Processing Record 43 of Set 12| balabac)
# Processing Record 44 of Set 12| pustomyty)
# Processing Record 45 of Set 12| hamilton)
# Processing Record 46 of Set 12| bolshiye uki)
# bolshiye uki not found... Skipping!
# Processing Record 47 of Set 12| warqla)
# warqla not found... Skipping!
# Processing Record 48 of Set 12| sedona)
# Processing Record 49 of Set 12| mandan)
# Processing Record 1 of Set 13| maple creek)
# Processing Record 2 of Set 13| athabasca)
# Processing Record 3 of Set 13| tessalit)
# Processing Record 4 of Set 13| huarmey)
# Processing Record 5 of Set 13| andrews)
# Processing Record 6 of Set 13| kuche)
# kuche not found... Skipping!
# Processing Record 7 of Set 13| araouane)
# -----------------------------------------
# Beginning Data Complete
# -----------------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#List of values to be extracted
data_extract=["name","clouds.all","sys.country","dt","main.humidity","coord.lat","coord.lon", "main.temp_max","wind.speed","main.temp"]

#Extracting required data
required_weather_data=[response(*data_extract) for response in weather_data]

#Defining column names for the DataFrame
column_names=["City","Cloudiness","Country","Date","Humidity","Lat","Lng","Max Temp","Wind Speed","Current Temp"]

#Building the DataFrame
df_weather_data=pd.DataFrame(required_weather_data,columns=column_names)

#Writing to a CSV file
df_weather_data.to_csv(output_data_file, index=False,header=True)

#Previewing DataFrame
df_weather_data.head()
# Out:
# 534
#                 City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0         Nelson Bay          90      AU  1574541248        93 -32.72  152.14
# 1  Careiro da Varzea          75      BR  1574541248        70  -3.20  -59.81
# 2              Asosa         100      ET  1574541248        74  10.07   34.53
# 3        Velka Bites          90      CZ  1574541248        80  49.29   16.23
# 4            Mataura           5      NZ  1574541248        66 -46.19  168.86
#
#    Max Temp  Wind Speed  Current Temp
# 0     66.99        5.88         64.78
# 1     87.80        2.24         87.80
# 2     69.19        3.31         69.19
# 3     46.00       20.80         42.60
# 4     62.01       15.99         62.01

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# First scatter plot: Latitude vs Max Temperature
date = time.strftime("%m/%d/%y", time.localtime(df_weather_data["Date"][0]))
plt.scatter(x=df_weather_data["Lat"],y=df_weather_data["Max Temp"], edgecolors="black",facecolor="lightblue")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.title(f"City Latitude vs. Max Temperature ({date})")
# Out:
# Text(0.5, 1.0, 'City Latitude vs. Max Temperature (11/23/19)')

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# First scatter plot: Latitude vs Humidity
plt.scatter(x=df_weather_data["Lat"],y=df_weather_data["Humidity"], edgecolors="black",facecolor="skyblue")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title(f"City Latitude vs. Humidity ({date})")
# Out:
# Text(0.5, 1.0, 'City Latitude vs. Humidity (11/23/19)')

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# First scatter plot: Latitude vs Cloudiness
plt.scatter(x=df_weather_data["Lat"],y=df_weather_data["Cloudiness"], edgecolors="black",facecolor="skyblue")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title(f"City Latitude vs. Cloudiness ({date})")
# Out:
# Text(0.5, 1.0, 'City Latitude vs. Cloudiness (11/23/19)')

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# First scatter plot: Latitude vs Wind Speed
plt.scatter(x=df_weather_data["Lat"],y=df_weather_data["Wind Speed"], edgecolors="black",facecolor="skyblue")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title(f"City Latitude vs. Wind Speed({date})")
# Out:
# Text(0.5, 1.0, 'City Latitude vs. Wind Speed(11/23/19)')
